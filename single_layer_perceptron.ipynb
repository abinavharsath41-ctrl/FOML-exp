# %% [markdown]
# <a href="https://colab.research.google.com/github/abinavharsath41-ctrl/FOML-exp/blob/main/single_layer_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# a. Training inputs (x1, x2)
X = np.array([
    [0, 0],
        [0, 1],
            [1, 0],
                [1, 1]
                ])

# %%
# b. Desired outputs Y
Y = np.array([0, 0, 0, 1])

# c. Initial weights
W = np.array([0.3, -0.2])

# d. Threshold and bias
theta = 0.4
bias = -theta

# e. Learning rate
eta = 0.2

# Step 3: Training the perceptron
print("Initial Weights:", W)
print("Initial Bias:", bias)

# %%
epochs = 10
for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}")

# %%
 total_error = 0

# %%
 for i in range(len(X)):
            # a. Compute net input
                    net = np.dot(X[i], W) + bias
